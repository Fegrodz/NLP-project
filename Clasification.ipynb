# %% [markdown]
# ## Modelo de clasificación usando Naive Bayes

# %%
# Agregamos las bibliotecas necesarias
import re
import string
import locale
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import numpy as np
from sklearn.model_selection import train_test_split # Biblioteca usada para partir el modelo en grupos de entrenamiento y prueba

# %% [markdown]
# Agregamos el dataframe en formato de Document-Term Matrix(DTM), para trabajarlo y usarlo para el modelo de clasificación, además del dataframe con la corpora para saber a que clase pertenecen cada texto.

# %%
df_corpus = pd.read_pickle("df_corpus.pkl")
data_dtm = pd.read_pickle("df_DTM.pkl")

# %% [markdown]
# Verificamos cuales son las dimenciones de nuestros dataframes:

# %%
df_corpus.shape
# Out:
# (104, 4)

# %%
df_corpus['categoria'].value_counts()
# Out:
# mantiene      72
# incrementa    18
# disminuye     14
# Name: categoria, dtype: int64

# %%
data_dtm.shape
# Out:
# (104, 2865)

# %% [markdown]
# Agregamos la columna de "Categoría" a df_corpus (que habíamos pasado por alto del ejercicio inicial de EDA).

# %%
df_corpus['categoria'] = df_corpus['text'].str.extract("(?P<category>mantiene|incrementa|disminuye)")
df_corpus.head()
# Out:
#                                                          text  \
# date
# 2008-02-15  El objetivo para la Tasa de Inter�s Interbanca...
# 2008-03-14  El objetivo para la Tasa de Inter�s Interbanca...
# 2008-04-18  El objetivo para la Tasa de Inter�s Interbanca...
# 2008-05-16  El objetivo para la Tasa de Inter�s Interbanca...
# 2008-06-20  El objetivo para la Tasa de Inter�s Interbanca...
#
#                                                           url  \
# date
# 2008-02-15  https://www.banxico.org.mx/publicaciones-y-pre...
# 2008-03-14  https://www.banxico.org.mx/publicaciones-y-pre...
# 2008-04-18  https://www.banxico.org.mx/publicaciones-y-pre...
# 2008-05-16  https://www.banxico.org.mx/publicaciones-y-pre...
# 2008-06-20  https://www.banxico.org.mx/publicaciones-y-pre...
#
#                                                     contenido   categoria
# date
# 2008-02-15    de febrero de  comunicado de prensa    anunc...    mantiene
# 2008-03-14    de marzo de  comunicado de prensa   anuncio ...    mantiene
# 2008-04-18   de abril de  comunicado de prensa anuncio de ...    mantiene
# 2008-05-16   de mayo de  comunicado de prensa  anuncio de ...    mantiene
# 2008-06-20   de junio de  comunicado de prensa  anuncio de...  incrementa

# %% [markdown]
# Partimos el conjunto de datos del dataframe data_dtm en dos, uno para entrenamiento y otro para probar la eficiencia del modelo, usando una proporción de 60% / 40% respectivamente. Además hacemos que nuestras etiquetas en "categoria" sean nuestras clases objetivo a clasificar.

# %%
X_train, X_test, y_train, y_test = train_test_split(data_dtm, df_corpus['categoria'], test_size=0.4, random_state=1)

# %% [markdown]
# Verificamos visualmente a los conjuntos usados para el entrenamiento:

# %%
X_train
# Out:
#             abastecimiento  abasto  abatimiento  abatir  abierto  abril  \
# date
# 2016-08-11               0       0            0       0        0      0
# 2010-03-19               0       0            0       0        0      0
# 2011-04-15               0       0            1       0        0      1
# 2018-04-12               0       0            0       0        0      1
# 2015-10-29               0       0            0       0        0      0
# ...                    ...     ...          ...     ...      ...    ...
# 2016-05-05               0       0            0       0        0      1
# 2008-11-28               0       0            0       0        0      0
# 2016-02-04               0       0            0       0        0      0
# 2009-03-20               0       0            0       0        0      0
# 2011-08-26               0       0            0       0        0      0
#
#             abriljunio  abrió  abrupta  absorber  ...  éstos  índice  índices  \
# date                                              ...
# 2016-08-11           0      0        0         1  ...      0       0        0
# 2010-03-19           0      0        0         0  ...      0       0        0
# 2011-04-15           0      0        0         0  ...      0       0        0
# 2018-04-12           0      0        0         0  ...      0       0        0
# 2015-10-29           0      0        0         0  ...      0       0        0
# ...                ...    ...      ...       ...  ...    ...     ...      ...
# 2016-05-05           0      0        0         0  ...      0       0        0
# 2008-11-28           0      0        1         0  ...      0       0        0
# 2016-02-04           0      1        0         0  ...      0       0        0
# 2009-03-20           0      0        0         0  ...      0       0        0
# 2011-08-26           0      0        0         0  ...      0       0        0
#
#             índole  última  últimas  último  últimos  ﬁancladasﬂ  ﬁanclajeﬂ
# date
# 2016-08-11       0       1        0       0        0           0          0
# 2010-03-19       0       0        0       0        0           0          0
# 2011-04-15       0       1        0       1        0           0          0
# 2018-04-12       0       1        0       0        0           0          0
# 2015-10-29       0       0        1       0        1           0          0
# ...            ...     ...      ...     ...      ...         ...        ...
# 2016-05-05       0       0        0       0        0           0          0
# 2008-11-28       0       0        0       1        0           0          0
# 2016-02-04       0       0        0       0        0           0          0
# 2009-03-20       0       0        1       1        0           0          0
# 2011-08-26       0       0        1       1        0           0          0
#
# [62 rows x 2865 columns]

# %%
print(X_train.shape)
# Out:
# (62, 2865)

# %%
X_test
# Out:
#             abastecimiento  abasto  abatimiento  abatir  abierto  abril  \
# date
# 2018-12-20               0       0            0       0        0      0
# 2011-05-27               0       0            0       0        0      1
# 2017-02-09               0       0            0       0        0      0
# 2014-06-06               0       0            0       0        0      1
# 2011-10-14               0       0            0       0        0      0
# 2011-12-02               0       0            0       0        0      0
# 2013-09-06               0       0            0       0        0      0
# 2017-08-10               0       0            0       0        0      0
# 2010-11-26               0       0            0       0        0      0
# 2014-01-31               0       0            0       0        0      0
# 2019-03-28               0       0            0       1        1      0
# 2012-10-26               0       0            0       0        0      0
# 2018-05-17               0       0            0       0        0      1
# 2014-04-25               0       0            0       0        0      1
# 2011-03-04               0       0            0       0        0      0
# 2017-12-14               0       0            0       0        0      0
# 2019-11-14               0       0            0       1        0      0
# 2016-12-15               0       0            0       0        0      0
# 2009-08-21               0       0            0       0        0      0
# 2019-08-15               0       0            0       1        0      0
# 2015-06-04               0       0            0       0        0      1
# 2017-03-30               0       0            0       0        0      0
# 2015-04-30               0       0            0       0        0      1
# 2012-07-20               0       0            0       0        0      0
# 2012-04-27               0       0            0       0        0      2
# 2013-10-25           0      0        0         0  ...      0       0        1
# 2013-12-06           0      0        0         0  ...      0       0        0
#
#             índole  última  últimas  último  últimos  ﬁancladasﬂ  ﬁanclajeﬂ
# date
# 2018-12-20       0       1        0       1        1           0          0
# 2011-05-27       0       1        1       1        0           0          0
# 2017-02-09       0       1        1       0        0           0          0
# 2014-06-06       0       0        0       1        1           0          0
# 2011-10-14       0       1        1       0        0           0          0
# 2011-12-02       0       0        1       0        0           0          0
# 2013-09-06       0       0        0       0        0           0          0
# 2017-08-10       0       1        0       0        0           0          0
# 2010-11-26       0       0        1       1        1           0          0
# 2014-01-31       0       0        1       0        1           0          0
# 2019-03-28       0       1        0       0        0           0          0
# 2012-10-26       0       0        0       0        1           0          0
# 2018-05-17       1       0        0       0        0           0          0
# 2014-04-25       0       0        1       0        0           0          0
# 2011-03-04       0       1        0       1        1           0          0
# 2017-12-14       0       1        0       0        0           0          0
# 2019-11-14       0       1        1       0        1           0          0
# 2016-12-15       0       1        0       1        0           0          0
# 2009-08-21       0       0        0       1        1           0          0
# 2019-08-15       0       0        0       0        0           0          0
# 2015-06-04       0       0        1       0        0           0          0
# 2017-03-30       0       1        0       0        0           0          0
# 2015-04-30       0       1        0       0        1           0          0
# 2012-07-20       0       0        1       0        1           0          0
# 2012-04-27       0       0        1       1        1           0          0
# 2012-01-20       0       0        0       1        1           0          0
# 2017-05-18       0       3        0       1        0           0          0
# 2017-09-28       0       1        2       0        0           0          0
# 2013-01-18       0       0        0       0        0           0          0
# 2011-07-08       0       1        0       1        0           0          0
# 2009-01-16       0       0        1       2        0           0          0
# 2008-04-18       0       0        0       1        0           0          0
# 2011-01-21       0       0        0       1        2           0          0
# 2015-09-21       0       0        2       0        0           0          0
# 2009-10-16       0       0        0       0        1           0          0
# 2010-07-16       0       0        0       0        0           0          0
# 2014-10-31       0       0        0       1        0           0          0
# 2019-05-16       0       1        0       0        0           0          0
# 2016-09-29       0       1        0       0        0           0          0
# 2016-03-18       0       0        1       0        0           0          0
# 2013-10-25       0       1        0       0        0           0          0
# 2013-12-06       0       0        0       1        0           0          0
#
# [42 rows x 2865 columns]

# %%
print(X_test.shape)
# Out:
# (42, 2865)

# %%
y_train
# Out:
# date
# 2016-08-11     mantiene
# 2010-03-19     mantiene
# 2011-04-15     mantiene
# 2018-04-12     mantiene
# 2015-10-29     mantiene
#                 ...
# 2016-05-05     mantiene
# 2008-11-28     mantiene
# 2016-02-04     mantiene
# 2009-03-20    disminuye
# 2011-08-26     mantiene
# Name: categoria, Length: 62, dtype: object

# %%
print(y_test)
# Out:
# date
# 2018-12-20    incrementa
# 2011-05-27      mantiene
# 2017-02-09    incrementa
# 2014-06-06     disminuye
# 2011-10-14      mantiene
# 2011-12-02      mantiene
# 2013-09-06     disminuye
# 2017-08-10      mantiene
# 2010-11-26      mantiene
# 2014-01-31      mantiene
# 2019-03-28      mantiene
# 2012-10-26      mantiene
# 2018-05-17      mantiene
# 2014-04-25      mantiene
# 2011-03-04      mantiene
# 2017-12-14    incrementa
# 2019-11-14     disminuye
# 2016-12-15    incrementa
# 2009-08-21      mantiene
# 2019-08-15     disminuye
# 2015-06-04      mantiene
# 2017-03-30    incrementa
# 2015-04-30      mantiene
# 2012-07-20      mantiene
# 2012-04-27      mantiene
# 2012-01-20      mantiene
# 2017-05-18    incrementa
# 2017-09-28      mantiene
# 2013-01-18      mantiene
# 2011-07-08      mantiene
# 2009-01-16     disminuye
# 2008-04-18      mantiene
# 2011-01-21      mantiene
# 2015-09-21      mantiene
# 2009-10-16      mantiene
# 2010-07-16      mantiene
# 2014-10-31      mantiene
# 2019-05-16      mantiene
# 2016-09-29    incrementa
# 2016-03-18      mantiene
# 2013-10-25     disminuye
# 2013-12-06      mantiene
# Name: categoria, dtype: object

# %%
print(y_test.shape)
# Out:
# (42,)

# %% [markdown]
# Model Building and Evaluation
#
# Let's build the Text Classification Model using TF-IDF.
#
# First, import the MultinomialNB module and create a Multinomial Naive Bayes classifier object using MultinomialNB() function.
#
# Then, fit your model on a train set using fit() and perform prediction on the test set using predict().

# %%
from sklearn.naive_bayes import MultinomialNB
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6904761904761905

# %% [markdown]
# En este caso, revisamos la matriz de confusión para ver otros parámetros de prueba de precisión del modelo:

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted)
# Out:
# array([[ 0,  0,  6],
#        [ 0,  0,  7],
#        [ 0,  0, 29]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# mantiene      29
# incrementa     7
# disminuye      6
# Name: categoria, dtype: int64

# %%
unique, counts = np.unique(predicted, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'mantiene': 42}

# %% [markdown]
# Normalizamos el conjunto de datos inicial y lo pasamos nuevamente al modelo

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
text_tf= tf.fit_transform(df_corpus['contenido'])

# %%
X_train, X_test, y_train, y_test = train_test_split(text_tf, df_corpus['categoria'], test_size=0.4, random_state=123)

# %% [markdown]
# Probamos la eficiencia del modelo normalizado:

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6904761904761905

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted)
# Out:
# array([[ 0,  0,  7],
#        [ 0,  0,  6],
#        [ 0,  0, 29]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# mantiene      29
# disminuye      7
# incrementa     6
# Name: categoria, dtype: int64

# %%
unique, counts = np.unique(predicted, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'mantiene': 42}

# %% [markdown]
# Como se puede notar, el modelo no logra clasificar con exactitud las clases de "disminuye" y "aumenta".
